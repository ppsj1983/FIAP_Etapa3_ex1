# %%
import oracledb
import pandas as pd
from tabulate import tabulate

# Conexão com o banco de dados Oracle
conn = oracledb.connect(
    user='rm567787',
    password='281083',
    dsn='oracle.fiap.com.br:1521/ORCL'
)
cursor = conn.cursor()
cursor.execute("SELECT * FROM DADOS_SENSORES ")
colunas = [col[0] for col in cursor.description]
dados = cursor.fetchall()
df = pd.DataFrame(dados, columns=colunas)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

print(tabulate(df.head(20), headers='keys', tablefmt='grid'))

# %%
import oracledb
import pandas as pd
from tabulate import tabulate

# Conexão com o banco de dados Oracle
conn = oracledb.connect(
    user='rm567787',
    password='281083',
    dsn='oracle.fiap.com.br:1521/ORCL'
)
cursor = conn.cursor()
cursor.execute("SELECT * FROM DADOS_SENSORES WHERE CROP_TYPE = 'Wheat'")
colunas = [col[0] for col in cursor.description]
dados = cursor.fetchall()
df = pd.DataFrame(dados, columns=colunas)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

print(tabulate(df.head(20), headers='keys', tablefmt='grid'))

# %%
import oracledb
import pandas as pd
from tabulate import tabulate

# Conexão com o banco de dados Oracle
conn = oracledb.connect(
    user='rm567787',
    password='281083',
    dsn='oracle.fiap.com.br:1521/ORCL'
)
cursor = conn.cursor()
cursor.execute("SELECT * FROM DADOS_SENSORES WHERE CROP_TYPE = 'Wheat' and IRRIGATION_TYPE = 'Drip'")
colunas = [col[0] for col in cursor.description]
dados = cursor.fetchall()
df = pd.DataFrame(dados, columns=colunas)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

print(tabulate(df.head(20), headers='keys', tablefmt='grid'))

# %%
import oracledb
import pandas as pd
from tabulate import tabulate

# Conexão com o banco de dados Oracle
conn = oracledb.connect(
    user='rm567787',
    password='281083',
    dsn='oracle.fiap.com.br:1521/ORCL'
)
cursor = conn.cursor()
cursor.execute("SELECT * FROM DADOS_SENSORES WHERE CROP_TYPE <> 'Wheat' AND SOIL_PH > 700")
colunas = [col[0] for col in cursor.description]
dados = cursor.fetchall()
df = pd.DataFrame(dados, columns=colunas)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

print(tabulate(df.head(20), headers='keys', tablefmt='grid'))

# %%
import oracledb
import pandas as pd
from tabulate import tabulate

# Conexão com o banco de dados Oracle
conn = oracledb.connect(
    user='rm567787',
    password='281083',
    dsn='oracle.fiap.com.br:1521/ORCL'
)
cursor = conn.cursor()
cursor.execute("""
    SELECT * FROM DADOS_SENSORES
    WHERE CROP_TYPE <> 'Wheat'
      AND SOIL_PH > 700
      AND HARVEST_DATE BETWEEN TO_DATE('01/05/2024', 'DD/MM/YYYY') AND TO_DATE('30/07/2024', 'DD/MM/YYYY')
""")
colunas = [col[0] for col in cursor.description]
dados = cursor.fetchall()
df = pd.DataFrame(dados, columns=colunas)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

print(tabulate(df.head(20), headers='keys', tablefmt='grid'))
